# %% [markdown]
# # Export Model

# %%
from sentence_transformers import SentenceTransformer
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
model_name = "../output/NeoBERTugues-matryoshka-sts-pt-loss-v2/checkpoint-2640"
repo_name = "iara-project/NeoBERTugues-matryoshka-sts-pt-v2"

# %%
model = SentenceTransformer(model_name)
# Out:
# Loading weights: 100%|██████████| 134/134 [00:00<00:00, 3587.42it/s]

# %%
model.push_to_hub(repo_name)
# Out:
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.52it/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (0 / 1):   0%|          |  557kB /  540MB,  696kB/s
# Processing Files (0 / 1):   0%|          | 1.11MB /  540MB,  928kB/s
# Processing Files (0 / 1):   1%|          | 3.34MB /  540MB, 2.39MB/s
# Processing Files (0 / 1):   1%|▏         | 7.24MB /  540MB, 4.52MB/s
# Processing Files (0 / 1):   3%|▎         | 13.9MB /  540MB, 7.74MB/s
# Processing Files (0 / 1):   3%|▎         | 18.4MB /  540MB, 9.19MB/s
# Processing Files (0 / 1):   5%|▍         | 26.2MB /  540MB, 11.9MB/s
# Processing Files (0 / 1):   7%|▋         | 35.1MB /  540MB, 14.6MB/s
# Processing Files (0 / 1):   7%|▋         | 36.8MB /  540MB, 14.1MB/s
# Processing Files (0 / 1):   8%|▊         | 41.2MB /  540MB, 14.7MB/s
# Processing Files (0 / 1):   9%|▉         | 47.3MB /  540MB, 15.8MB/s
# Processing Files (0 / 1):  10%|▉         | 51.8MB /  540MB, 16.2MB/s
# Processing Files (0 / 1):  11%|█         | 60.7MB /  540MB, 17.9MB/s
# Processing Files (0 / 1):  12%|█▏        | 66.8MB /  540MB, 18.6MB/s
# Processing Files (0 / 1):  13%|█▎        | 71.0MB /  540MB, 14.8MB/s
# Processing Files (0 / 1):  14%|█▎        | 73.2MB /  540MB, 14.6MB/s
# Processing Files (0 / 1):  14%|█▍        | 76.0MB /  540MB, 14.6MB/s
# Processing Files (0 / 1):  15%|█▍        | 80.4MB /  540MB, 14.9MB/s
# Processing Files (0 / 1):  16%|█▌        | 86.5MB /  540MB, 15.4MB/s
# Processing Files (0 / 1):  18%|█▊        | 95.4MB /  540MB, 16.4MB/s
# Processing Files (0 / 1):  19%|█▊        |  101MB /  540MB, 16.8MB/s
# Processing Files (0 / 1):  20%|██        |  110MB /  540MB, 17.7MB/s
# Processing Files (0 / 1):  23%|██▎       |  121MB /  540MB, 19.0MB/s
# Processing Files (0 / 1):  24%|██▍       |  129MB /  540MB, 19.6MB/s
# Processing Files (0 / 1):  27%|██▋       |  143MB /  540MB, 21.0MB/s
# Processing Files (0 / 1):  30%|██▉       |  161MB /  540MB, 23.0MB/s
# Processing Files (0 / 1):  34%|███▎      |  181MB /  540MB, 25.2MB/s
# Processing Files (0 / 1):  37%|███▋      |  197MB /  540MB, 26.7MB/s
# Processing Files (0 / 1):  41%|████      |  221MB /  540MB, 29.1MB/s
# Processing Files (0 / 1):  45%|████▌     |  245MB /  540MB, 31.4MB/s
# Processing Files (0 / 1):  49%|████▉     |  265MB /  540MB, 33.2MB/s
# Processing Files (0 / 1):  53%|█████▎    |  287MB /  540MB, 35.1MB/s
# Processing Files (0 / 1):  58%|█████▊    |  315MB /  540MB, 37.4MB/s
# Processing Files (0 / 1):  63%|██████▎   |  340MB /  540MB, 39.6MB/s
# Processing Files (0 / 1):  66%|██████▌   |  354MB /  540MB, 40.3MB/s
# Processing Files (0 / 1):  69%|██████▉   |  374MB /  540MB, 41.6MB/s
# Processing Files (0 / 1):  72%|███████▏  |  386MB /  540MB, 42.0MB/s
# Processing Files (0 / 1):  74%|███████▍  |  399MB /  540MB, 42.5MB/s
# Processing Files (0 / 1):  75%|███████▍  |  405MB /  540MB, 42.2MB/s
# Processing Files (0 / 1):  76%|███████▌  |  411MB /  540MB, 41.9MB/s
# Processing Files (0 / 1):  77%|███████▋  |  417MB /  540MB, 41.7MB/s
# Processing Files (0 / 1):  79%|███████▉  |  426MB /  540MB, 41.7MB/s
# Processing Files (0 / 1):  80%|████████  |  432MB /  540MB, 42.4MB/s
# Processing Files (0 / 1):  82%|████████▏ |  442MB /  540MB, 43.3MB/s
# Processing Files (0 / 1):  83%|████████▎ |  449MB /  540MB, 44.0MB/s
# Processing Files (0 / 1):  84%|████████▍ |  453MB /  540MB, 44.4MB/s
# Processing Files (0 / 1):  84%|████████▍ |  455MB /  540MB, 44.5MB/s
# Processing Files (0 / 1):  85%|████████▌ |  460MB /  540MB, 44.9MB/s
# Processing Files (0 / 1):  86%|████████▌ |  463MB /  540MB, 45.1MB/s
# Processing Files (0 / 1):  87%|████████▋ |  467MB /  540MB, 45.1MB/s
# Processing Files (0 / 1):  87%|████████▋ |  468MB /  540MB, 44.6MB/s
# Processing Files (0 / 1):  88%|████████▊ |  472MB /  540MB, 44.5MB/s
# Processing Files (0 / 1):  88%|████████▊ |  476MB /  540MB, 44.1MB/s
# Processing Files (0 / 1):  89%|████████▉ |  480MB /  540MB, 43.6MB/s
# Processing Files (0 / 1):  89%|████████▉ |  481MB /  540MB, 43.6MB/s
# Processing Files (0 / 1):  89%|████████▉ |  482MB /  540MB, 42.6MB/s
# Processing Files (0 / 1):  89%|████████▉ |  482MB /  540MB, 42.2MB/s
# Processing Files (0 / 1):  89%|████████▉ |  483MB /  540MB, 40.8MB/s
# Processing Files (0 / 1):  90%|████████▉ |  483MB /  540MB, 40.8MB/s
# Processing Files (0 / 1):  90%|████████▉ |  484MB /  540MB, 40.9MB/s
# Processing Files (0 / 1):  90%|████████▉ |  484MB /  540MB, 40.9MB/s
# Processing Files (0 / 1):  90%|████████▉ |  485MB /  540MB, 41.0MB/s
# Processing Files (0 / 1):  90%|████████▉ |  485MB /  540MB, 40.4MB/s
# Processing Files (0 / 1):  90%|█████████ |  486MB /  540MB, 40.2MB/s
# Processing Files (0 / 1):  90%|█████████ |  486MB /  540MB, 39.8MB/s
# Processing Files (0 / 1):  90%|█████████ |  487MB /  540MB, 39.3MB/s
# Processing Files (0 / 1):  90%|█████████ |  487MB /  540MB, 38.4MB/s
# Processing Files (0 / 1):  90%|█████████ |  488MB /  540MB, 37.9MB/s
# Processing Files (0 / 1):  91%|█████████ |  489MB /  540MB, 37.1MB/s
# Processing Files (0 / 1):  91%|█████████ |  489MB /  540MB, 36.0MB/s
# Processing Files (0 / 1):  91%|█████████ |  490MB /  540MB, 35.3MB/s
# Processing Files (0 / 1):  91%|█████████ |  490MB /  540MB, 34.0MB/s
# Processing Files (0 / 1):  91%|█████████ |  491MB /  540MB, 32.4MB/s
# Processing Files (0 / 1):  91%|█████████ |  492MB /  540MB, 30.5MB/s
# Processing Files (0 / 1):  91%|█████████ |  492MB /  540MB, 28.9MB/s
# Processing Files (0 / 1):  91%|█████████▏|  494MB /  540MB, 26.7MB/s
# Processing Files (0 / 1):  92%|█████████▏|  494MB /  540MB, 24.4MB/s
# Processing Files (0 / 1):  92%|█████████▏|  495MB /  540MB, 22.5MB/s
# Processing Files (0 / 1):  92%|█████████▏|  496MB /  540MB, 20.4MB/s
# Processing Files (0 / 1):  92%|█████████▏|  497MB /  540MB, 17.9MB/s
# Processing Files (0 / 1):  92%|█████████▏|  498MB /  540MB, 15.5MB/s
# Processing Files (0 / 1):  93%|█████████▎|  500MB /  540MB, 14.2MB/s
# Processing Files (0 / 1):  93%|█████████▎|  501MB /  540MB, 12.4MB/s
# Processing Files (0 / 1):  93%|█████████▎|  502MB /  540MB, 11.4MB/s
# Processing Files (0 / 1):  93%|█████████▎|  503MB /  540MB, 10.2MB/s
# Processing Files (0 / 1):  93%|█████████▎|  505MB /  540MB, 9.80MB/s
# Processing Files (0 / 1):  94%|█████████▍|  506MB /  540MB, 9.35MB/s
# Processing Files (0 / 1):  94%|█████████▍|  508MB /  540MB, 8.86MB/s
# Processing Files (0 / 1):  94%|█████████▍|  509MB /  540MB, 8.15MB/s
# Processing Files (0 / 1):  95%|█████████▍|  511MB /  540MB, 7.72MB/s
# Processing Files (0 / 1):  95%|█████████▌|  513MB /  540MB, 6.96MB/s
# Processing Files (0 / 1):  95%|█████████▌|  514MB /  540MB, 6.36MB/s
# Processing Files (0 / 1):  96%|█████████▌|  517MB /  540MB, 6.25MB/s
# Processing Files (0 / 1):  96%|█████████▌|  519MB /  540MB, 6.31MB/s
# Processing Files (0 / 1):  97%|█████████▋|  522MB /  540MB, 6.09MB/s
# Processing Files (0 / 1):  97%|█████████▋|  523MB /  540MB, 5.87MB/s
# Processing Files (0 / 1):  97%|█████████▋|  526MB /  540MB, 5.76MB/s
# Processing Files (0 / 1):  98%|█████████▊|  528MB /  540MB, 5.87MB/s
# Processing Files (0 / 1):  99%|█████████▊|  532MB /  540MB, 5.81MB/s
# Processing Files (0 / 1):  99%|█████████▊|  533MB /  540MB, 5.59MB/s
# Processing Files (0 / 1):  99%|█████████▉|  536MB /  540MB, 5.54MB/s
# Processing Files (0 / 1): 100%|█████████▉|  539MB /  540MB, 5.65MB/s
# Processing Files (0 / 1): 100%|█████████▉|  539MB /  540MB, 5.70MB/s
# Processing Files (1 / 1): 100%|██████████|  540MB /  540MB, 5.57MB/s
# Processing Files (1 / 1): 100%|██████████|  540MB /  540MB, 5.44MB/s
# New Data Upload: 100%|██████████|  540MB /  540MB, 5.44MB/s
# 'https://huggingface.co/iara-project/NeoBERTugues-matryoshka-sts-pt-v2/commit/0e1e8ad141ea3bbb685d8586e33b1f2041b3860f'
